# %% [markdown]
# # # Stable Diffusion Run
# ---

# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %%
# import os
# os.kill(os.getpid(), 9) # This will crash Colab (required, everything will still be intact so dont worry)

# %% [markdown]
# Clone webui repository

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 4192, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 4192 (delta 16), reused 22 (delta 11), pack-reused 4157
# Receiving objects: 100% (4192/4192), 20.24 MiB | 51.56 MiB/s, done.
# Resolving deltas: 100% (2941/2941), done.
# /content/stable-diffusion-webui

# %% [markdown]
# Download the model from huggingface. See link at the start for different ways.

# %%
#@title Normal 1.4 model
# get a token from https://huggingface.co/settings/tokens
user_token = "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" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
# Out:
# --2022-10-04 00:22:52--  https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt
# Resolving huggingface.co (huggingface.co)... 54.173.5.192, 52.5.54.249, 54.210.225.113, ...
# Connecting to huggingface.co (huggingface.co)|54.173.5.192|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22 [following]
# --2022-10-04 00:22:53--  https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.154.185.26, 18.154.185.64, 18.154.185.94, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.154.185.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265380512 (4.0G) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt’
#
# /content/stable-dif 100%[===================>]   3.97G   232MB/s    in 16s
#
# 2022-10-04 00:23:09 (252 MB/s) - ‘/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt’ saved [4265380512/4265380512]

# %% [markdown]
# Voldy doesn't explian what this does but it appears to replace the prior dependencies section, saving a few lines lmao

# %%
# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: 3f417566b0bda8eab05d247567aebf001c1d1725
# Installing gfpgan
# Cloning Stable Diffusion into repositories/stable-diffusion...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Exiting because of --exit argument

# %% [markdown]
# Change into Web UI directory and download updates

# %%
# %cd stable-diffusion-webui
# !git pull
# Out:
# [Errno 2] No such file or directory: 'stable-diffusion-webui'
# /content/stable-diffusion-webui
# Already up to date.

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug --gradio-auth 1:1" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: 2865ef4b9ab16d56326cc805541bebcf01d099bc
# Installing gfpgan
# Installing clip
# Cloning Stable Diffusion into repositories/stable-diffusion...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --gradio-auth 1:1
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Downloading: 100% 939k/939k [00:00<00:00, 5.81MB/s]
# Downloading: 100% 512k/512k [00:00<00:00, 3.57MB/s]
# Downloading: 100% 389/389 [00:00<00:00, 480kB/s]
# Downloading: 100% 905/905 [00:00<00:00, 975kB/s]
# Downloading: 100% 4.41k/4.41k [00:00<00:00, 4.07MB/s]
# Downloading: 100% 1.59G/1.59G [00:22<00:00, 75.8MB/s]
# Loading weights [7460a6fa] from /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
# Global Step: 470000
# Model loaded.
# Loaded a total of 0 textual inversion embeddings.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://26393.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:04<01:16,  4.02s/it]
#  15% 3/20 [00:04<00:18,  1.10s/it]
#  25% 5/20 [00:04<00:08,  1.72it/s]
#  35% 7/20 [00:04<00:04,  2.71it/s]
#  45% 9/20 [00:04<00:02,  3.83it/s]
#  55% 11/20 [00:04<00:01,  5.03it/s]
#  65% 13/20 [00:05<00:01,  6.27it/s]
#  75% 15/20 [00:05<00:00,  7.39it/s]
#  85% 17/20 [00:05<00:00,  8.44it/s]
# 100% 20/20 [00:05<00:00,  3.58it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.11it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.45it/s]
#  20% 4/20 [00:00<00:01, 11.78it/s]
#  30% 6/20 [00:00<00:01, 11.94it/s]
#  40% 8/20 [00:00<00:00, 12.01it/s]
#  50% 10/20 [00:00<00:00, 11.90it/s]
#  60% 12/20 [00:01<00:00, 11.99it/s]
#  70% 14/20 [00:01<00:00, 12.02it/s]
#  80% 16/20 [00:01<00:00, 12.07it/s]
#  90% 18/20 [00:01<00:00, 12.04it/s]
# 100% 20/20 [00:01<00:00, 11.97it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.10it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.51it/s]
#  20% 4/20 [00:00<00:01, 11.84it/s]
#  30% 6/20 [00:00<00:01, 12.03it/s]
#  40% 8/20 [00:00<00:00, 12.07it/s]
#  50% 10/20 [00:00<00:00, 11.98it/s]
#  60% 12/20 [00:01<00:00, 12.04it/s]
#  70% 14/20 [00:01<00:00, 12.08it/s]
#  80% 16/20 [00:01<00:00, 12.06it/s]
#  90% 18/20 [00:01<00:00, 12.08it/s]
# 100% 20/20 [00:01<00:00, 12.03it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.25it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.53it/s]
#  20% 4/20 [00:00<00:01, 11.88it/s]
#  30% 6/20 [00:00<00:01, 11.89it/s]
#  40% 8/20 [00:00<00:00, 12.01it/s]
#  50% 10/20 [00:00<00:00, 11.98it/s]
#  60% 12/20 [00:01<00:00, 12.03it/s]
#  70% 14/20 [00:01<00:00, 12.04it/s]
#  80% 16/20 [00:01<00:00, 12.01it/s]
#  90% 18/20 [00:01<00:00, 12.04it/s]
# 100% 20/20 [00:01<00:00, 11.97it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.34it/s]
# Warning: unknown mime-type for "outputs/txt2img-images" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'outputs/txt2img-images'
# Warning: unknown mime-type for "outputs/txt2img-images" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'outputs/txt2img-images'
# Warning: unknown mime-type for "outputs/txt2img-images" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'outputs/txt2img-images'
# Warning: unknown mime-type for "outputs/txt2img-images" -- using "application/octet-stream"
# Error: no "view" mailcap rules found for type "application/octet-stream"
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'outputs/txt2img-images'
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.17it/s]
#  20% 4/20 [00:00<00:01, 11.65it/s]
#  30% 6/20 [00:00<00:01, 11.84it/s]
#  40% 8/20 [00:00<00:01,  8.56it/s]
#  50% 10/20 [00:01<00:01,  9.55it/s]
#  60% 12/20 [00:01<00:00, 10.29it/s]
#  70% 14/20 [00:01<00:00, 10.82it/s]
#  80% 16/20 [00:01<00:00, 11.19it/s]
#  90% 18/20 [00:01<00:00, 11.36it/s]
# 100% 20/20 [00:01<00:00, 10.79it/s]
# Total progress: 100% 20/20 [00:01<00:00, 10.20it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.17it/s]
#  20% 4/20 [00:00<00:01, 11.34it/s]
#  30% 6/20 [00:00<00:01, 11.62it/s]
#  40% 8/20 [00:00<00:01, 11.73it/s]
#  50% 10/20 [00:00<00:00, 11.73it/s]
#  60% 12/20 [00:01<00:00, 11.81it/s]
#  70% 14/20 [00:01<00:00, 11.87it/s]
#  80% 16/20 [00:01<00:00, 11.92it/s]
#  90% 18/20 [00:01<00:00, 11.99it/s]
# 100% 20/20 [00:01<00:00, 11.81it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.01it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.27it/s]
#  20% 4/20 [00:00<00:01, 11.33it/s]
#  30% 6/20 [00:00<00:01, 11.77it/s]
#  40% 8/20 [00:00<00:01, 11.98it/s]
#  50% 10/20 [00:00<00:00, 11.91it/s]
#  60% 12/20 [00:01<00:00, 12.04it/s]
#  70% 14/20 [00:01<00:00, 12.08it/s]
#  80% 16/20 [00:01<00:00, 12.14it/s]
#  90% 18/20 [00:01<00:00, 12.19it/s]
# 100% 20/20 [00:01<00:00, 12.00it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.33it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.16it/s]
#  20% 4/20 [00:00<00:01, 11.59it/s]
#  30% 6/20 [00:00<00:01, 11.79it/s]
#  40% 8/20 [00:00<00:01, 11.93it/s]
#  50% 10/20 [00:00<00:00, 11.87it/s]
#  60% 12/20 [00:01<00:00, 11.93it/s]
#  70% 14/20 [00:01<00:00, 12.00it/s]
#  80% 16/20 [00:01<00:00, 12.06it/s]
#  90% 18/20 [00:01<00:00, 12.04it/s]
# 100% 20/20 [00:01<00:00, 11.90it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.49it/s]
#   0% 0/20 [00:00<?, ?it/s]
#  10% 2/20 [00:00<00:01, 11.35it/s]
#  20% 4/20 [00:00<00:01, 11.71it/s]
#  30% 6/20 [00:00<00:01, 11.93it/s]
#  40% 8/20 [00:00<00:00, 12.03it/s]
#  50% 10/20 [00:00<00:00, 11.98it/s]
#  60% 12/20 [00:01<00:00, 12.05it/s]
#  70% 14/20 [00:01<00:00, 12.01it/s]
#  80% 16/20 [00:01<00:00, 12.03it/s]
#  90% 18/20 [00:01<00:00, 12.09it/s]
# 100% 20/20 [00:01<00:00, 11.99it/s]
# Total progress: 100% 20/20 [00:01<00:00, 11.34it/s]

# %% [markdown]
# # # commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
