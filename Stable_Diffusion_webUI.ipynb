# %%
# !nvidia-smi
# Out:
# Thu Oct  6 11:10:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # # Stable Diffusion Run
# ---

# %% [markdown]
# Adapted from: https://colab.research.google.com/drive/1AfAmwLMd_Vx33O9IwY2TmO9wKZ8ABRRa

# %%
# import os
# os.kill(os.getpid(), 9) # This will crash Colab (required, everything will still be intact so dont worry)

# %% [markdown]
# Clone webui repository

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 4419, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 4419 (delta 18), reused 9 (delta 4), pack-reused 4380
# Receiving objects: 100% (4419/4419), 20.32 MiB | 59.45 MiB/s, done.
# Resolving deltas: 100% (3101/3101), done.
# /content/stable-diffusion-webui

# %% [markdown]
# Download the model from huggingface. See link at the start for different ways.

# %%
#@title Normal 1.4 model
# get a token from https://huggingface.co/settings/tokens
user_token = "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" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""
# !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
# Out:
# --2022-10-06 11:14:31--  https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt
# Resolving huggingface.co (huggingface.co)... 44.195.102.200, 54.210.225.113, 52.5.54.249, ...
# Connecting to huggingface.co (huggingface.co)|44.195.102.200|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1665295344&Policy=...&Signature=k4NYpc-js2hL~irpRW8VYWRXucKYePTH8~XsX4sJE-OlzHHahz-CSr7d4ehrbSNaau5MWqwsJCgsQ8nEMHFome6cpy8gqTClR64yBotw5w-HmrW141WPRDTe~DITkihD51Xe3ZiJE64iyFICBEj09nHl2S4McOceUw4STzqBERD60C2L2SOzyTBD6S7C2ZZNvAVYBmr5IlNe~dvHfMZK11EBiLGPg1niOvh4b5q2nH8auy6G2nrYA5JfN4BAJipU~GArasmhjUpgEpBGXUtzqeexQk9lYpGcnRnRDZhuYjubshz-BiXooHbDrzbTI4wJGBLwfXJGby-1nqQZBV8jFQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2022-10-06 11:14:31--  https://cdn-lfs.huggingface.co/repos/4c/37/4c372b4ebb57bbd02e68413d4951aa326d4b3cfb6e62db989e529c6d4b26fb21/fe4efff1e174c627256e44ec2991ba279b3816e364b49f9be2abc0b3ff3f8556?response-content-disposition=attachment%3B%20filename%3D%22sd-v1-4.ckpt%22&Expires=1665295344&Policy=...&Signature=k4NYpc-js2hL~irpRW8VYWRXucKYePTH8~XsX4sJE-OlzHHahz-CSr7d4ehrbSNaau5MWqwsJCgsQ8nEMHFome6cpy8gqTClR64yBotw5w-HmrW141WPRDTe~DITkihD51Xe3ZiJE64iyFICBEj09nHl2S4McOceUw4STzqBERD60C2L2SOzyTBD6S7C2ZZNvAVYBmr5IlNe~dvHfMZK11EBiLGPg1niOvh4b5q2nH8auy6G2nrYA5JfN4BAJipU~GArasmhjUpgEpBGXUtzqeexQk9lYpGcnRnRDZhuYjubshz-BiXooHbDrzbTI4wJGBLwfXJGby-1nqQZBV8jFQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 108.156.83.76, 108.156.83.35, 108.156.83.123, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|108.156.83.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265380512 (4.0G) [binary/octet-stream]
# Saving to: ‘/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt’
#
# /content/stable-dif 100%[===================>]   3.97G   154MB/s    in 27s
#
# 2022-10-06 11:14:58 (152 MB/s) - ‘/content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt’ saved [4265380512/4265380512]

# %% [markdown]
# Voldy doesn't explian what this does but it appears to replace the prior dependencies section, saving a few lines lmao

# %%
# !COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# Change into Web UI directory and download updates

# %%
# %pwd
# Out:
# '/content/stable-diffusion-webui'

# %%
# %cd stable-diffusion-webui
# !git pull
# Out:
# [Errno 2] No such file or directory: 'stable-diffusion-webui'
# /content/stable-diffusion-webui
# Already up to date.

# %% [markdown]
# Launch web ui. You will get a link to nnn.gradio.app, follow it.
#
# Commandline arguments are:
#   - `--share` - create online gradio.app link
#   - `--gradio-debug` - print outputs to console
#   - `--gradio-auth me:qwerty` - add authentication to gradio: username me, password qwerty

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug --gradio-auth 1:1" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.7.14 (default, Sep  8 2022, 00:06:44)
# [GCC 7.5.0]
# Commit hash: 2a532804957e47bc36c67c8f5b104dcfa8e8f3f0
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug --gradio-auth 1:1
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Downloading: 100% 939k/939k [00:00<00:00, 8.22MB/s]
# Downloading: 100% 512k/512k [00:00<00:00, 5.59MB/s]
# Downloading: 100% 389/389 [00:00<00:00, 579kB/s]
# Downloading: 100% 905/905 [00:00<00:00, 1.44MB/s]
# Downloading: 100% 4.41k/4.41k [00:00<00:00, 6.07MB/s]
# Downloading: 100% 1.59G/1.59G [00:20<00:00, 81.6MB/s]
# Loading weights [7460a6fa] from /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-4.ckpt
# Global Step: 470000
# Model loaded.
# Loaded a total of 0 textual inversion embeddings.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://11782.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:03<01:12,  3.82s/it]
#  10% 2/20 [00:04<00:30,  1.69s/it]
#  15% 3/20 [00:04<00:17,  1.01s/it]
#  20% 4/20 [00:04<00:11,  1.45it/s]
#  25% 5/20 [00:04<00:07,  1.96it/s]
#  30% 6/20 [00:04<00:05,  2.46it/s]
#  35% 7/20 [00:05<00:04,  2.95it/s]
#  40% 8/20 [00:05<00:03,  3.40it/s]
#  45% 9/20 [00:05<00:02,  3.79it/s]
#  50% 10/20 [00:05<00:02,  4.12it/s]
#  55% 11/20 [00:05<00:02,  4.35it/s]
#  60% 12/20 [00:06<00:01,  4.52it/s]
#  65% 13/20 [00:06<00:01,  4.67it/s]
#  70% 14/20 [00:06<00:01,  4.78it/s]
#  75% 15/20 [00:06<00:01,  4.87it/s]
#  80% 16/20 [00:06<00:00,  4.90it/s]
#  85% 17/20 [00:07<00:00,  4.93it/s]
#  90% 18/20 [00:07<00:00,  4.96it/s]
#  95% 19/20 [00:07<00:00,  4.99it/s]
# 100% 20/20 [00:07<00:00,  2.63it/s]
# Total progress: 100% 20/20 [00:04<00:00,  4.85it/s]
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:05,  3.48it/s]
#  15% 3/20 [00:00<00:03,  4.60it/s]
#  20% 4/20 [00:00<00:03,  4.78it/s]
#  25% 5/20 [00:01<00:03,  4.88it/s]
#  30% 6/20 [00:01<00:02,  4.87it/s]
#  35% 7/20 [00:01<00:02,  4.86it/s]
#  40% 8/20 [00:01<00:02,  4.91it/s]
#  45% 9/20 [00:01<00:02,  4.96it/s]
#  50% 10/20 [00:02<00:02,  4.99it/s]
#  55% 11/20 [00:02<00:01,  4.96it/s]
#  60% 12/20 [00:02<00:01,  4.96it/s]
#  65% 13/20 [00:02<00:01,  4.97it/s]
#  70% 14/20 [00:02<00:01,  4.98it/s]
#  75% 15/20 [00:03<00:01,  4.99it/s]
#  80% 16/20 [00:03<00:00,  4.95it/s]
#  85% 17/20 [00:03<00:00,  4.94it/s]
#  90% 18/20 [00:03<00:00,  4.95it/s]
#  95% 19/20 [00:03<00:00,  4.96it/s]
# 100% 20/20 [00:04<00:00,  4.88it/s]
# Total progress: 20it [00:04,  4.86it/s]

# %% [markdown]
# # # commands for ***after*** you have gotten done with a session
# ============================================================================

# %% [markdown]
# Zip images for downloading on local drive (click the folder icon on the left, the one below {x})

# %%
# !zip -r /content/stable-diffusion-webui /content/stable-diffusion-webui/outputs

# %% [markdown]
# Save images to Google Drive **Warning: this will cause google to scan your drive, so if you intend to use this and worry about that kind of stuff, probablly just set this up on a clean account that's just for this colab**

# %%
from google.colab import drive # type: ignore

try:
   drive_path = "/content/drive"
   drive.mount(drive_path,force_remount=False)
except:
   print("...error mounting drive or with drive path variables")

# !cp -r "/content/stable-diffusion-webui/outputs" "/content/drive/MyDrive"
